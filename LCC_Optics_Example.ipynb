# %% [markdown]
# Author: Georgios Katsanevakis, Kyriacos Skoufaris
#
#
# The following is an example of use for all the functions, starting from the nominal lattice strengths/elements provided in the acc model gitlab:  https://acc-models.web.cern.ch/acc-models/
#
# To run this file requires the acc-model merged dipole lattice for 106.2, the normal and skew response matrices, my function file, a dictionary with the desired misalignment errors (to be generated from a python file that is inlcuded) and a python environment for xsuite.
# The procedure to make such an environment is outlined in https://xsuite.readthedocs.io/en/latest/installation.html

# %%
import numpy as np
import xtrack as xt
import xobjects as xo
import pickle
import yaml

#file available at https://gitlab.cern.ch/kskoufar/xutil/-/blob/master/xsuite_utilities.py?ref_type=heads
# import xsuite_utilities as xutil

################
import xsuite_utilities2 as xutil

#################

#this is the file with my functions
import functions_for_misalignments as fn
import importlib
importlib.reload(fn)
#allows plot manipulations
# %matplotlib widget

#defining variables to be used later on
acc_model_path = 'acc_models_fcc_ee_LCC_106.2.0'  # https://gitlab.cern.ch/acc-models/fcc/acc-models-fcc-ee/-/tree/LCC_106.2.0?ref_type=tags
particle = 'positron'
operation_mode = 'z'
file_name = 'fccee_z_merged_dipoles'

#dictionary with study parameters
study_param={}
#number of turns for tracking
study_param['number_of_turns'] = 2500
#normalised emittances
study_param['ini_cond_nemittance_x'] = 0.7138e-9
study_param['ini_cond_nemittance_y'] = 0.7138e-12
study_param['ini_cond_type'] = 'grid_MA'
study_param['ini_cond_bunch_length']=0.004860455626868767
study_param['ini_cond_energy_spread']=0.0003736678561994034

# %%
#Load environment from acc models
env = xt.Environment.from_json(f'{acc_model_path}/lattices/{operation_mode}/{file_name}.json')

line = env.lines['fccee_p_ring']
line.config.XTRACK_USE_EXACT_DRIFTS = False

# #Set the local context
# context = xo.ContextCpu()         # For CPU
# context_tracking = xo.ContextCpu(omp_num_threads='auto') # For CPU with activate multi-core CPU parallelization

# # Transfer lattice on context and compile tracking code
# line.build_tracker(_context=context)

# Cycle the line now to have the correct initialitation of the beam 
line.cycle(name_first_element='rf400', inplace=True)
# Out:
# Warning: The environment you are loading was created with xtrack version 0.99.6, which is more recent than the current version 0.99.4. Some features may not be available or may not work correctly. Please update your xsuite package to the latest version.
# Loading line from dict:   0%|          | 0/14697 [00:00<?, ?it/s]
# Line(mode=normal, 21288 elements)

# %%
# Introduce orbit corrector elements.
fn.add_steering_correctors(line, corrector_names=['Quadrupole'], corrector_prefix=['hcor_', 'vcor_'],corrector_plane='hv')
tt = line.get_table(attr=True)

# Optics correctors introduced to ideal line, needed to compute the response matrix. 
optics_correctors=fn.add_optics_correctors(line, corrector_names = ['Sextupole'], corector_type = [['knl1']])
skew_optics_correctors=fn.add_optics_correctors(line, corrector_names = ['Sextupole'], corector_type = [['ksl1']])

# %%
# Remove syncrhotron radiation for optics and orbit correction
line.configure_radiation(model=None, model_beamstrahlung=None)


## Since the sexutpoles will be turned off, computing the chromatic properties might cause problems. Full reference twiss is computed after the sextupole ramping.
tw_ref = line.twiss4d(compute_chromatic_properties=False,coupling_edw_teng=True)

ideal_line=line.copy()

# %%
#Loading the dictionary with the parameters for the errors
with open('misalignment_parameters.yaml', 'r') as f:
    misalignment_errors = yaml.safe_load(f)
seed=misalignment_errors['arc_quads']['error_seed']

#Introducing the misalignments and rotations to the line elements
misalignment_arc_quad=fn.add_misalignment_error(line,misalignment_errors['arc_quads'])

misalignment_dipole=fn.add_misalignment_error(line, misalignment_errors['arc_dipoles'])

misalignment_sextupole=fn.add_misalignment_error(line, misalignment_errors['arc_sextupoles'])

misalignment_girder=fn.add_misalignment_error(line, misalignment_errors['girder'])

misalignment_quad_SS=fn.add_misalignment_error(line, misalignment_errors['SS_quads'])

misalignment_non_arc_dipoles=fn.add_misalignment_error(line, misalignment_errors['non_arc_dipoles'])

misalignment_fd_to_cs=fn.add_misalignment_error(line, misalignment_errors['fd_to_cs'])

misalignment_final_doublet=fn.add_misalignment_error(line, misalignment_errors['final_doublet'])

misalignment_bpm=fn.add_misalignment_error(line, misalignment_errors['bpm'] )


# #Knobs to control what misalignments are applied. By default the variable is 1 (100% of the assigned value)
# line.vars['misalignment_dipoles']
# line.vars['misalignment_quads']
# line.vars['misalignment_sextupoles']
# line.vars['misalignment_girder'] 
# line.vars['misalignment_ss_quads']
# line.vars['misalignment_non_arc_dipoles'
# line.vars['misalignment_fd_to_cs']
# line.vars['misalignment_final_doublet']


tt = line.get_table(attr=True)

# %%
#Turning off the sextupoles
#if custom flag is True, the names of the sextupoles to be modified can be given manually through the "family_name" input. An example input would be family_name='S[FD][12][AB].*' 
#the variable to control the sextupole strengths will be k2n.weight_{family_name} in this case 'k2n.weight_S[FD][12][AB].*'
# fn.sextupoles_strength_edit2 (line, family_name='S[FD][12][AB].*|S[FD][1234][CIJDFM][LR].*', error_strength=0, custom=True)
# fn.sextupoles_strength_edit2 (line, family_name='SCRAB[LR].*|S[FD][MXY][12][LR].*', error_strength=0, custom=True)

fn.sextupoles_strength_edit2(line, family_name='ir', error_strength=0)
fn.sextupoles_strength_edit2(line, family_name='arc', error_strength=0)

# %%
# #add here the function to randomly exclude some orbit correctors or bpms
# element_list=[tt.rows['bpm.*'].name] #/ [tt.rows['hcor.*'].name] / tt.rows['vcor.*'].name
# switch_rate = 0.1 #each element has a 10% chance of being removed
# new_element_list, removed_element_list= fn.off_switch(element_list, switch_rate)



#Assign the BPM's as steering monitors for the line
steering_monitors=tt.rows['bpm.*'].name
line.steering_monitors_x = steering_monitors
line.steering_monitors_y = steering_monitors

#Assign the orbit correctors as steering correctors for the line
line.steering_correctors_x = tt.rows['hcor.*'].name
line.steering_correctors_y = tt.rows['vcor.*'].name

#Initialisation of the orbit correction routine. 'run=False' allows for evaluation of the orbit response matrix without applying the correction, 
#providing the singular values used to find the cutoff BPM misalignments are introduced through the 'monitor_alignment' parameter
orbit_correction = line.correct_trajectory(twiss_table=tw_ref,monitor_alignment=misalignment_bpm, run=False)

#Singular values of the orbit correction, used to determine the cutoff 
x_sv = orbit_correction.x_correction.singular_values
y_sv = orbit_correction.y_correction.singular_values

#Amount of singular values used in orbit correction. This value has been determined for LCC v106.2.
# It is possible to introduce the misalignments adiabatically (with the aforementioned knobs) and avoid the SVD orbit cutoff.
cutoff=1300

#Sometimes threading is neccessary. 'delta0=0' ensures no radiation efffects are considered. Performing 2 SVD's seemed to provide an improved solution without significant computational
#time increase. 

#To be checked: PySC functionality for orbit correction https://indico.cern.ch/event/1663665/contributions/6994658/attachments/3242228/5783534/20260320_pySC_and_commissioning_simulations_petra4.pdf

#The orbit correction can also be performed with MICADO. n_micado controls the amount of correctors in each plane that will be used, and 
#n_iter the amount of iterations performed. n_micado and n_iter need to be optimised, random values are provided below.
# orbit_correction = line.correct_trajectory(twiss_table=tw_ref, n_micado=12,n_iter=4)



try:
    orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
    orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
except Exception as e:
    print(f"Threading Neccessary: {e}")
    threader = orbit_correction.thread(ds_thread=4000, rcond_long=1e-5)
    orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
    orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)


#Ramp up the sextupoles (arc and ir can be ramped separately or together)
for i in [0.25, 0.5, 0.75,1]:
    line.vars['k2n.weight_arc']=i
    # line.vars['k2n.weight_ir']=i

    orbit_correction = line.correct_trajectory(twiss_table=tw_ref,monitor_alignment=misalignment_bpm, run=False)

    x_sv = orbit_correction.x_correction.singular_values
    y_sv = orbit_correction.y_correction.singular_values
    try:
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
    except Exception as e:
        print(f"Threading Neccessary: {e}")
        threader = orbit_correction.thread(ds_thread=4000, rcond_long=1e-5) 
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)

for i in [0.25, 0.5, 0.75,1]:
    line.vars['k2n.weight_ir']=i
    orbit_correction = line.correct_trajectory(twiss_table=tw_ref,monitor_alignment=misalignment_bpm, run=False)
    x_sv = orbit_correction.x_correction.singular_values
    y_sv = orbit_correction.y_correction.singular_values
    try:
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
    except Exception as e:
        print(f"Threading Neccessary: {e}")
        threader = orbit_correction.thread(ds_thread=4000, rcond_long=1e-5) #1e-7
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)
        orbit_correction.correct(n_singular_values=(cutoff,cutoff),delta0=0)

    try:
        fn.match_tune_chroma(line, tw_ref, match_quantities='tune')
    except Exception as e:
        print(f"Tune matching failed: {e}")
# Out:
# Warning! Need second attempt on closed orbit search
#
#
# Threading Neccessary:
# Stop at s=4000, global rms = [x: 2.32e-04 -> 4.64e-06, y: 2.72e-04 -> 1.12e-05]
# Stop at s=8000, global rms = [x: 3.83e-04 -> 3.59e-06, y: 8.46e-04 -> 7.62e-06]
# Stop at s=12000, global rms = [x: 4.18e-03 -> 3.97e-06, y: 3.32e-03 -> 9.80e-06]
# Stop at s=16000, global rms = [x: 6.04e-03 -> 4.85e-05, y: 1.61e-02 -> 1.06e-04]
# Stop at s=20000, global rms = [x: 1.42e-04 -> 2.32e-06, y: 4.70e-04 -> 5.22e-06]
# Stop at s=24000, global rms = [x: 7.86e-05 -> 2.38e-06, y: 4.04e-04 -> 4.82e-06]
# Stop at s=28000, global rms = [x: 4.71e-05 -> 1.61e-06, y: 5.60e-05 -> 4.43e-06]
# Stop at s=32000, global rms = [x: 1.98e-04 -> 2.04e-06, y: 2.08e-04 -> 4.38e-06]
# Stop at s=36000, global rms = [x: 3.56e-03 -> 7.23e-06, y: 5.21e-04 -> 6.95e-06]
# Stop at s=40000, global rms = [x: 4.04e-05 -> 6.81e-06, y: 1.42e-04 -> 4.81e-06]
# Stop at s=44000, global rms = [x: 4.23e-05 -> 6.45e-06, y: 8.97e-05 -> 4.57e-06]
# Stop at s=48000, global rms = [x: 1.16e-04 -> 6.28e-06, y: 1.75e-04 -> 4.45e-06]
# Stop at s=52000, global rms = [x: 1.20e-04 -> 6.02e-06, y: 1.31e-04 -> 4.29e-06]
# Stop at s=56000, global rms = [x: 1.01e-04 -> 5.80e-06, y: 6.99e-05 -> 4.10e-06]
# Stop at s=60000, global rms = [x: 1.78e-03 -> 6.81e-06, y: 1.99e-04 -> 6.56e-06]
# Stop at s=64000, global rms = [x: 4.13e-05 -> 6.59e-06, y: 1.51e-04 -> 4.52e-06]
# Stop at s=68000, global rms = [x: 1.68e-04 -> 6.37e-06, y: 6.27e-05 -> 4.44e-06]
# Stop at s=72000, global rms = [x: 3.42e-05 -> 6.22e-06, y: 2.63e-05 -> 4.28e-06]
# Stop at s=76000, global rms = [x: 9.03e-05 -> 6.13e-06, y: 1.98e-04 -> 4.18e-06]
# Stop at s=80000, global rms = [x: 4.63e-03 -> 6.55e-06, y: 6.11e-03 -> 5.76e-06]
# Stop at s=84000, global rms = [x: 6.30e-03 -> 2.66e-04, y: 1.07e-02 -> 2.66e-04]
# Stop at s=88000, global rms = [x: 3.30e-04 -> 5.84e-06, y: 3.86e-04 -> 4.97e-06]
# Stop at s=90644.83607569343, global rms = [x: 6.63e-05 -> 5.57e-06, y: 2.89e-05 -> 4.77e-06]
# Iteration 0, x_rms: 9.33e-05 -> 7.30e-06, y_rms: 6.37e-04 -> 3.74e-05
# Iteration 1, x_rms: 7.30e-06 -> 5.56e-06, y_rms: 3.74e-05 -> 5.78e-06
# Iteration 2, x_rms: 5.56e-06 -> 5.53e-06, y_rms: 5.78e-06 -> 4.60e-06
# Iteration 3, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.60e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.58e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.58e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.58e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.58e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.68e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
# Tune matching failed: One-turn matrix is unstable. Magnitudes of eigenvalues are:
# array([2.37194293, 1.        , 1.        , 0.42159531, 0.99999982,
#        0.99999982])
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.67e-06 -> 4.57e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.57e-06 -> 4.57e-06
#
# Optimize - start penalty: 0.09998
# Matching: model call n. 11 penalty = 7.7618e-08
# Optimize - end penalty:  7.76179e-08
# Target status:               nalty = 7.7618e-08
# id state tag  tol_met       residue   current_val    target_val description
# 0  ON    tune    True   5.54633e-09        194.16        194.16 'qx', val=194.16, tol=1e-05, weight=10
# 1  ON    tune    True  -5.42988e-09         170.2         170.2 'qy', val=170.2, tol=1e-05, weight=10
# Vary status:
# id state tag  met name lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON    quad OK  kqf2 None           0.00926946 None           0.00926927         1e-08             1
# 1  ON    quad OK  kqd1 None           -0.0136962 None           -0.0136956         1e-08             1
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.65e-06 -> 4.58e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.58e-06 -> 4.57e-06
#
# Optimize - start penalty: 0.1276
# Matching: model call n. 11 penalty = 3.4521e-07
# Optimize - end penalty:  3.45212e-07
# Target status:               nalty = 3.4521e-07
# id state tag  tol_met       residue   current_val    target_val description
# 0  ON    tune    True   2.42086e-08        194.16        194.16 'qx', val=194.16, tol=1e-05, weight=10
# 1  ON    tune    True  -2.46101e-08         170.2         170.2 'qy', val=170.2, tol=1e-05, weight=10
# Vary status:
# id state tag  met name lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON    quad OK  kqf2 None            0.0092693 None           0.00926946         1e-08             1
# 1  ON    quad OK  kqd1 None           -0.0136955 None           -0.0136962         1e-08             1
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.66e-06 -> 4.58e-06
# Iteration 0, x_rms: 5.53e-06 -> 5.53e-06, y_rms: 4.58e-06 -> 4.57e-06
#
# Optimize - start penalty: 0.1319
# Matching: model call n. 11 penalty = 1.3462e-06
# Optimize - end penalty:  1.34619e-06
# Target status:               nalty = 1.3462e-06
# id state tag  tol_met       residue   current_val    target_val description
# 0  ON    tune    True  -9.45354e-08        194.16        194.16 'qx', val=194.16, tol=1e-05, weight=10
# 1  ON    tune    True   9.58402e-08         170.2         170.2 'qy', val=170.2, tol=1e-05, weight=10
# Vary status:
# id state tag  met name lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON    quad OK  kqf2 None           0.00926916 None            0.0092693         1e-08             1
# 1  ON    quad OK  kqd1 None           -0.0136948 None           -0.0136955         1e-08             1

# %%
#Re-evaluate the reference twiss with chromatic functions and the coupling RDT's (mask 'coupling_edw_teng')
tw_ref = ideal_line.twiss4d(coupling_edw_teng=True)


#The response matrices are provided. To compute them (from the ideal line) the "response_matrix" function is to be used. 
# response_matrix=fn.response_matrix(ideal_line,observables=['mux', 'muy', 'dx'], obs_points=tt.rows['bpm.*'].name.tolist(), 
#                  corr_elements=[f"knl1{elem}" for elem in optics_correctors[1]], dk=1e-5, bipolar=True)

# skew_response_matrix=fn.response_matrix(ideal_line,observables=['f1001_real', 'f1001_imag','f1010_real', 'f1010_imag', 'dy'], obs_points=tt.rows['bpm.*'].name.tolist(), 
#                  corr_elements=[f"knl1{elem}" for elem in skew_optics_correctors[0]], dk=1e-5,rdt=None bipolar=True)


#Loading pre-computed responce matrix for normal quadrupole correctors
#'data' is a dictionary that contains the response matrix, the observables used, the observation points considered
#and the correctors used
with open("response_matrix(1e-5)_2.pkl", "rb") as f:
    data = pickle.load(f)
response = data["response"]
observables=data['observables']
obs_points=data["obs_points"]
corr_elements=data["corr_elements"]
corr_elements_func = [s[len("knl1"):] for s in corr_elements]

#Tikhonov regularisation. 'b' is the difference vector between the observables at the BPM's in the ideal and current line
#The tikhonov function returns a plot to verify the correct lambda was chosen, as well as its value, used in the computation
#of the pseudoinverse
b=fn.get_delta_vec(twiss=line.twiss4d(), reference_twiss=tw_ref,observables= observables)
lambda_opt, c_opt=fn.tikhonov_lcurve(response, b, lambdas=np.logspace(-5,20, 2000), plot=True, title=f"Normal {seed}")
pseudo_inverse=fn.pseudo_inverse(responce_matrix=response, Tikhonov_lambda=lambda_opt)

#Loading pre-computed responce matrix for skew quadrupole correctors
#'data' is a dictionary that contains the response matrix, the observables used, the observation points considered
#and the correctors used
with open("responce_matrix_rdt_1e-5_not_tog_moreBPM_2.pkl", "rb") as f:
    data_skew = pickle.load(f)
response_skew = data_skew["response"]
observables_skew=data_skew['observables']
obs_points_skew=data_skew["obs_points"]
corr_elements_skew=data_skew["corr_elements"]
corr_elements_func_skew = [s[len("ksl1"):] for s in corr_elements_skew]

#Regularisation for response matrix for skew correctors
b_skew=fn.get_delta_vec(twiss=line.twiss4d(coupling_edw_teng=True), reference_twiss=tw_ref,observables= observables_skew, rdt=True)
lambda_opt_skew, c_opt_skew=fn.tikhonov_lcurve(response_skew, b_skew, lambdas=np.logspace(-5,20, 2000), plot=True, title=f"Skew {seed}")
pseudo_inverse_skew=fn.pseudo_inverse(responce_matrix=response_skew, Tikhonov_lambda=lambda_opt_skew)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#5 iterations of optics correction. Chromaticity correction at the end. Further optics corrections
#can be performed after chromaticity, here was not found to affect results
for i in range(5):
    #Normal correctors are changed
    tw_optics=fn.optics_corrections(line,observables=observables,
                            observation_points=obs_points, reference_twiss=tw_ref, 
                            correctors=corr_elements, p_inverse=pseudo_inverse, weight=1)
    #Skew correctors are changed, flag "rdt=True" for coupling Resonance Driving Terms  as observables                    
    tw_optics_skew=fn.optics_corrections(line,observables=observables_skew,
                            observation_points=obs_points_skew, reference_twiss=tw_ref, 
                            correctors=corr_elements_skew, p_inverse=pseudo_inverse_skew, rdt=True, weight=1)

#Chromaticity correction
fn.match_tune_chroma(line, tw_ref, match_quantities='chroma')

tw_optics_skew=line.twiss4d(coupling_edw_teng=True)
# Out:
#
# Optimize - start penalty: 0.3473
# Matching: model call n. 8 penalty = 3.6031e-07
# Optimize - end penalty:  3.60311e-07
# Target status:               alty = 3.6031e-07
# id state tag   tol_met       residue   current_val    target_val description
# 0  ON    chrom    True   3.91913e-08       12.1114       12.1114 'dqx', val=12.1114, tol=0.01, weight=1
# 1  ON    chrom    True   3.58173e-07       5.24097       5.24097 'dqy', val=5.24097, tol=0.01, weight=1
# Vary status:
# id state tag  met name lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON    sext OK  ksd2 None            -0.176481 None            -0.176755         0.001             1
# 1  ON    sext OK  ksf2 None             0.230749 None             0.230903         0.001             1
# 2  ON    sext OK  ksf1 None             0.319749 None             0.319897         0.001             1
# 3  ON    sext OK  ksd1 None            -0.266662 None            -0.266936         0.001             1

# %%
# #Plotting function to examine the results
# x,y=fn.closed_orbit_vs_s(tw_ref,  tw_optics_skew,  outline=None)
# print(f'DeltaQx : {(tw_ref.qx-tw_optics_skew.qx):.3g},  DeltaQy : {(tw_ref.qy-tw_optics_skew.qy):.3g}')
# dx_rms,dy_rms=fn.dispersion_deviation_vs_s(tw_ref, tw_optics_skew)
# betx_rms,bety_rms=fn.beta_beating_vs_s(tw_ref, tw_optics_skew, zoom=None)
# coupling_rms_re,coupling_rms_im=fn.coupling_vs_s(tw_optics_skew)
# rdt_rms = fn.coupling_rdt_single(tw_optics_skew)
# print(f'Chroma Diff x : {(tw_ref.dqx-tw_optics_skew.dqx):.3g},  Chroma Diff y : {(tw_ref.dqy-tw_optics_skew.dqy):.3g}')


import numpy as np
import matplotlib.pyplot as plt

# Compute singular values
_, s_normal, _ = np.linalg.svd(response, full_matrices=False)
_, s_skew, _ = np.linalg.svd(response_skew, full_matrices=False)

# Define cutoffs
cutoff_normal = 22  # adjust as needed
cutoff_skew = 22    # adjust as needed

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Normal response matrix
ax1.semilogy(s_normal, 'r.', markersize=3)
ax1.axhline(y=cutoff_normal, color='k', linestyle='--', 
            label=f'cutoff = {cutoff_normal:.1e}')
ax1.set_xlabel('Index', fontweight='bold')
ax1.set_ylabel('Singular value', fontweight='bold')
ax1.set_title('Singular Value Spectrum (X)', fontweight='bold')
ax1.legend()
ax1.grid(True)

# Skew response matrix
ax2.semilogy(s_skew, 'r.', markersize=3)
ax2.axhline(y=cutoff_skew, color='k', linestyle='--',
            label=f'cutoff = {cutoff_skew:.1e}')
ax2.set_xlabel('Index', fontweight='bold')
ax2.set_ylabel('Singular value', fontweight='bold')
ax2.set_title('Singular Value Spectrum (Y)', fontweight='bold')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.savefig('singular_value_spectrum.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
#Introduce Synchrotron Radiation and compensate its effects with magnetic tapering for both the line with errors and the ideal one
line.configure_radiation(model='mean')
line.compensate_radiation_energy_loss()

ideal_line.configure_radiation(model='mean')
ideal_line.compensate_radiation_energy_loss()

#One iteration of optics correction to correct the phase advances 
tw_optics=fn.optics_corrections(line,observables=observables,
                        observation_points=obs_points, reference_twiss=tw_ref, 
                        correctors=corr_elements, p_inverse=pseudo_inverse, Delta_mu=False,radiation=True, weight=1)
tw_optics_skew=fn.optics_corrections(line,observables=observables_skew,
                        observation_points=obs_points_skew, reference_twiss=tw_ref, 
                        correctors=corr_elements_skew, p_inverse=pseudo_inverse_skew, rdt=True, radiation=True, weight=1)

#Match the chromaticity after enabling radiation
fn.match_tune_chroma(line, tw_ref, match_quantities='chroma')

#Compute twiss with "eneloss_and_damping=True" flag to consider synchrotron radiation
tw_optics_skew=line.twiss(coupling_edw_teng=True, eneloss_and_damping=True)
tw_ref = ideal_line.twiss(coupling_edw_teng=True, eneloss_and_damping=True)
# Out:
# Compensating energy loss.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 #Introduce Synchrotron Radiation and compensate its effects with magnetic tapering for both the line with errors and the ideal one
#       2 line.configure_radiation(model='mean')
# ----> 3 line.compensate_radiation_energy_loss()
#       5 ideal_line.configure_radiation(model='mean')
#       6 ideal_line.compensate_radiation_energy_loss()
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/line.py:3617, in Line.compensate_radiation_energy_loss(self, delta0, rtol_eneloss, max_iter, **kwargs)
#    3615 all_kwargs.update(kwargs)
#    3616 self._check_valid_tracker()
# -> 3617 compensate_radiation_energy_loss(self, **all_kwargs)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/tapering.py:43, in compensate_radiation_energy_loss(line, delta0, rtol_eneloss, max_iter, verbose, co_search_at, **kwargs)
#      41 with xt.line._preserve_track_flags(line):
#      42     line.tracker.track_flags.XS_FLAG_KILL_CAVITY_KICK = True
# ---> 43     particle_on_co = line.find_closed_orbit(co_search_at=co_search_at)
#      44 line.config.XTRACK_MULTIPOLE_NO_SYNRAD = False
#      46 beta0 = float(particle_on_co._xobject.beta0[0])
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/line.py:2097, in Line.find_closed_orbit(self, co_guess, particle_ref, co_search_settings, delta0, zeta0, zeta_shift, continue_on_closed_orbit_error, freeze_longitudinal, start, end, num_turns, co_search_at, search_for_t_rev, spin, num_turns_search_t_rev, symmetrize, include_collective)
#    2094 else:
#    2095     line = self
# -> 2097 return find_closed_orbit_line(line, co_guess=co_guess,
#    2098                          particle_ref=particle_ref,
#    2099                          delta0=delta0, zeta0=zeta0, zeta_shift=zeta_shift,
#    2100                          co_search_settings=co_search_settings,
#    2101                          continue_on_closed_orbit_error=continue_on_closed_orbit_error,
#    2102                          start=start, end=end, num_turns=num_turns,
#    2103                          co_search_at=co_search_at,
#    2104                          search_for_t_rev=search_for_t_rev,
#    2105                          spin=spin,
#    2106                          num_turns_search_t_rev=num_turns_search_t_rev,
#    2107                          symmetrize=symmetrize)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/twiss.py:2900, in find_closed_orbit_line(line, co_guess, particle_ref, co_search_settings, zeta_shift, delta0, zeta0, start, end, num_turns, co_search_at, search_for_t_rev, continue_on_closed_orbit_error, num_turns_search_t_rev, symmetrize, spin)
#    2891 opt = xt.match.opt_from_callable(
#    2892     lambda p: _error_for_co(p, co_guess, line,
#    2893                     zeta_shift, delta0, zeta0, start=start,
#    (...)   2897         tar=[0., 0., 0., 0., 0., 0.],
#    2898         tols=[1e-12, 1e-12, 1e-12, 1e-12, 1e-12, 1e-12])
#    2899 try:
# -> 2900     opt.solve(verbose=-1)
#    2901     ier = 1
#    2902 except Exception as e:
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xdeps/optimize/optimize.py:1107, in Optimize.solve(self, n_steps, verbose, take_best, rcond, sing_val_cutoff, broyden)
#    1105 try:
#    1106     self.solver.x = self._err._knobs_to_x(self._extract_knob_values())
# -> 1107     self.step(n_steps, verbose=verbose, take_best=take_best, rcond=rcond, sing_val_cutoff=sing_val_cutoff, broyden=broyden)
#    1109     if not self._err.last_point_within_tol:
#    1110         _print("\n")
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xdeps/optimize/optimize.py:1030, in Optimize.step(self, n_steps, take_best, enable_target, enable_vary, enable_vary_name, disable_target, disable_vary, disable_vary_name, rcond, sing_val_cutoff, verbose, broyden)
#    1027         if i_step % (broyden + 1) == 0:
#    1028             this_broyden = False
# -> 1030 self.solver.step(
#    1031     rcond=rcond, sing_val_cutoff=sing_val_cutoff, broyden=this_broyden)
#    1032 self._log["penalty"].append(self.solver.penalty_after_last_step)
#    1033 if hasattr(self.solver, "_last_jac_svd"):
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xdeps/optimize/jacobian.py:70, in JacobianSolver.step(self, n_steps, rcond, sing_val_cutoff, broyden)
#      68     jac = self._last_jac + np.outer(dy - np.dot(self._last_jac, dx), dx) / np.dot(dx, dx)
#      69 else:
# ---> 70     jac = myf.get_jacobian(self.x, f0=y)
#      71 self._last_jac_x = self.x.copy()
#      72 self._last_jac = jac.copy()
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xdeps/optimize/optimize.py:408, in MeritFunctionForMatch.get_jacobian(self, x, f0)
#     406         continue
#     407     x[ii] += steps[ii]
# --> 408     jac[:, ii] = (self(x, check_limits=False) - f0) / steps[ii]
#     409     x[ii] -= steps[ii]
#     411 self._last_jac = jac
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xdeps/optimize/optimize.py:290, in MeritFunctionForMatch.__call__(self, x, check_limits, return_scalar, zero_if_met)
#     288 failed = False
#     289 for aa in self.actions:
# --> 290     res_data[aa] = aa.run()
#     291     if isinstance(res_data[aa], str) and res_data[aa] == "failed":
#     292         failed = True
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xdeps/optimize/optimize.py:1879, in ActionCall.run(self)
#    1877 def run(self):
#    1878     x = [vv.container[vv.name] for vv in self.vary]
# -> 1879     return self.function(x)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/twiss.py:2892, in find_closed_orbit_line.<locals>.<lambda>(p)
#    2888     ier = 1
#    2889     break
#    2891 opt = xt.match.opt_from_callable(
# -> 2892     lambda p: _error_for_co(p, co_guess, line,
#    2893                     zeta_shift, delta0, zeta0, start=start,
#    2894                     end=end, num_turns=num_turns,
#    2895                     symmetrize=symmetrize),
#    2896         x0=x0, steps=[1e-8, 1e-9, 1e-8, 1e-9, 1e-7, 1e-8],
#    2897         tar=[0., 0., 0., 0., 0., 0.],
#    2898         tols=[1e-12, 1e-12, 1e-12, 1e-12, 1e-12, 1e-12])
#    2899 try:
#    2900     opt.solve(verbose=-1)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/twiss.py:2965, in _error_for_co_search_6d(p, co_guess, line, zeta_shift, delta0, zeta0, start, end, num_turns, symmetrize)
#    2964 def _error_for_co_search_6d(p, co_guess, line, zeta_shift, delta0, zeta0, start, end, num_turns, symmetrize):
# -> 2965     return p - _one_turn_map(p, co_guess, line, zeta_shift, start, end, num_turns, symmetrize)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/twiss.py:2946, in _one_turn_map(p, particle_ref, line, zeta_shift, start, end, num_turns, symmetrize)
#    2942     dp0c = line.energy_program.get_p0c_increse_per_turn_at_t_s(
#    2943                                                     line.vv['t_turn_s'])
#    2944     part.update_p0c_and_energy_deviations(p0c = part._xobject.p0c[0] + dp0c)
# -> 2946 line.track(part, ele_start=start, ele_stop=end, num_turns=num_turns)
#    2947 if symmetrize:
#    2948     assert num_turns == 1
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/line.py:1293, in Line.track(self, particles, ele_start, ele_stop, num_elements, num_turns, turn_by_turn_monitor, multi_element_monitor_at, freeze_longitudinal, time, with_progress, **kwargs)
#    1290 if not self._has_valid_tracker():
#    1291     self.build_tracker()
# -> 1293 return self.tracker._track(
#    1294     particles,
#    1295     ele_start=ele_start,
#    1296     ele_stop=ele_stop,
#    1297     num_elements=num_elements,
#    1298     num_turns=num_turns,
#    1299     turn_by_turn_monitor=turn_by_turn_monitor,
#    1300     freeze_longitudinal=freeze_longitudinal,
#    1301     time=time,
#    1302     with_progress=with_progress,
#    1303     multi_element_monitor_at=multi_element_monitor_at,
#    1304     **kwargs)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/tracker.py:389, in Tracker._track(self, particles, with_progress, time, multi_element_monitor_at, *args, **kwargs)
#     382         # particles.reorganize() # could be done in the future to optimize GPU usage
#     383 else:
#     384     multi_element_monitor = self._get_multi_element_monitor(
#     385         particles=particles,
#     386         multi_element_monitor_at=multi_element_monitor_at,
#     387         num_turns=kwargs.get('num_turns', 1)
#     388     )
# --> 389     out = tracking_func(particles, *args, **kwargs,
#     390                        multi_element_monitor=multi_element_monitor)
#     392 if time:
#     393     t1 = perf_counter()
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/tracker.py:1303, in Tracker._track_no_collective(self, particles, ele_start, ele_stop, num_elements, num_turns, turn_by_turn_monitor, freeze_longitudinal, backtrack, log, multi_element_monitor, _force_no_end_turn_actions, _reset_log)
#    1301 # First turn
#    1302 assert num_elements_first_turn >= 0
# -> 1303 track_kernel(
#    1304     buffer=tracker_data._buffer.buffer,
#    1305     tracker_data=tracker_data._element_ref_data,
#    1306     particles=particles._xobject,
#    1307     num_turns=1,
#    1308     ele_start=ele_start,
#    1309     num_ele_track=num_elements_first_turn,
#    1310     flag_end_turn_actions=flag_end_first_turn_actions,
#    1311     flag_reset_s_at_end_turn=self.reset_s_at_end_turn,
#    1312     flag_monitor=flag_monitor,
#    1313     num_ele_line=len(tracker_data.element_names),
#    1314     line_length=tracker_data.line_length,
#    1315     buffer_tbt_monitor=buffer_monitor,
#    1316     offset_tbt_monitor=offset_monitor,
#    1317     buffer_multi_element_monitor=buffer_multi_element_monitor,
#    1318     offset_multi_element_monitor=offset_multi_element_monitor,
#    1319     io_buffer=self.io_buffer.buffer,
#    1320     track_flags=track_flags
#    1321 )
#    1323 # Middle turns
#    1324 if num_middle_turns > 0:
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xobjects/context_cpu.py:854, in KernelCpu.__call__(self, **kwargs)
#     851     if isinstance(self.context.omp_num_threads, int):
#     852         self.context.omp_set_num_threads(self.context.omp_num_threads)
# --> 854 ret = self.function(*arg_list)
#     856 if self.description.ret is not None:
#     857     return self.from_function_arg(self.description.ret, ret)
#
# KeyboardInterrupt:

# %%
#Set the context for particle tracking to "auto" to reduce computational time
context = xo.ContextCpu()         # For CPU
context_tracking = xo.ContextCpu(omp_num_threads='auto') # For CPU with activate multi-core CPU parallelization

study_param['ini_cond_nemittance_x'] = tw_ref.eq_nemitt_x
study_param['ini_cond_nemittance_y'] = tw_ref.eq_nemitt_x/1000
study_param['number_of_turns'] = 2500


## Transfer lattice on context and compile tracking code
line.build_tracker(_context=context)

#Generate particle grid for Momentum Aceptance
if study_param['ini_cond_type'] == 'grid_MA':
    delta_initial_values = np.linspace(-0.015, 0.015, 100)
    particles_MA, grid_details_MA = xutil.generate_particle_grid (line, study_param, delta_initial_values=delta_initial_values, max_r_y=25) #, max_r_y=20

#Generate particle grid for Dynamic Apperture
study_param['ini_cond_type'] = 'grid_DA'
if study_param['ini_cond_type'] == 'grid_DA':
    particles_DA, grid_details_DA = xutil.generate_particle_grid (line, study_param, cartesian_polar='cartesian') # , max_r_y=30, 

#Enable quantum fluctuations
line.configure_radiation(model='quantum')
line.discard_tracker()
line.build_tracker(_context=context_tracking)

#Particle tracking for DA
line.track(particles_DA, num_turns=study_param['number_of_turns'], turn_by_turn_monitor=True, time=True, with_progress=10) 
particles_DA.sort(interleave_lost_particles=True)

#Plot of DA
if study_param['ini_cond_type'] == 'grid_DA':
    x_DA, y_DA, where_min_DA=fn.DA_vs_turns(particles_DA, grid_details_DA['num_r_y_points'], grid_details_DA['num_theta_x_points'], grid_details_DA['x_normalized'], grid_details_DA['y_normalized'], grid_details_DA['delta_init'])

#Particle tracking for MA
line.track(particles_MA, num_turns=study_param['number_of_turns'], turn_by_turn_monitor=True, time=True, with_progress=10) 
particles_MA.sort(interleave_lost_particles=True)
study_param['ini_cond_type'] = 'grid_MA'

#Plot of MA
if study_param['ini_cond_type'] == 'grid_MA':
    x_MA, delta_MA, where_min_MA=fn.MA_vs_turns(particles_MA, grid_details_MA['num_r_y_points'], grid_details_MA['num_delta'], grid_details_MA['x_normalized'], grid_details_MA['y_normalized'], grid_details_MA['delta_init'])
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f0ce17387d0>>
# Traceback (most recent call last):
#   File "/root/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 21
#      19 study_param['ini_cond_type'] = 'grid_DA'
#      20 if study_param['ini_cond_type'] == 'grid_DA':
# ---> 21     particles_DA, grid_details_DA = xutil.generate_particle_grid (line, study_param, cartesian_polar='cartesian') # , max_r_y=30,
#      23 #Enable quantum fluctuations
#      24 line.configure_radiation(model='quantum')
#
# File /mnt/c/Users/gkatsane/Documents/FCC/optics_corrections/Comparison_Lattice/xsuite_utilities2.py:2349, in generate_particle_grid(line, study_param, particle_capacity, cartesian_polar, min_r_y, max_r_y, num_r_y_points, min_theta_x, max_theta_x, num_theta_x_points, delta_initial_values, beambeam_strength_used, radiation_off, rnd_seed)
#    2346         dd_bb[jj] = line[jj].scale_strength
#    2347         line[jj].scale_strength = beambeam_strength_used
# -> 2349 tw = line.twiss(eneloss_and_damping=True)
#    2350 ref_part = line.particle_ref
#    2351 if 'grid' in study_param['ini_cond_type']:
#    2352     # The longitudinal closed orbit needs to be manually supplied for now
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/line.py:1567, in Line.twiss(self, particle_ref, method, particle_on_co, R_matrix, W_matrix, delta0, zeta0, zeta_shift, r_sigma, nemitt_x, nemitt_y, delta_disp, delta_chrom, zeta_disp, co_guess, steps_r_matrix, co_search_settings, at_elements, at_s, continue_on_closed_orbit_error, freeze_longitudinal, freeze_energy, values_at_element_exit, radiation_method, eneloss_and_damping, radiation_integrals, start, end, init, num_turns, skip_global_quantities, matrix_responsiveness_tol, matrix_stability_tol, symplectify, reverse, use_full_inverse, strengths, hide_thin_groups, search_for_t_rev, num_turns_search_t_rev, only_twiss_init, only_markers, only_orbit, spin, polarization, compute_R_element_by_element, compute_lattice_functions, compute_chromatic_properties, coupling_edw_teng, init_at, x, px, y, py, zeta, delta, betx, alfx, bety, alfy, bets, dx, dpx, dy, dpy, dzeta, mux, muy, muzeta, ax_chrom, bx_chrom, ay_chrom, by_chrom, ddx, ddpx, ddy, ddpy, spin_x, spin_y, spin_z, zero_at, co_search_at, include_collective, disable_apertures, _continue_if_lost, _keep_tracking_data, _keep_initial_particles, _initial_particles, _ebe_monitor, ele_start, ele_stop, ele_init, twiss_init)
#    1564         tw_kwargs[kk] = vv
#    1566 tw_kwargs.pop('self')
# -> 1567 return twiss_line(self, **tw_kwargs)
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/twiss.py:427, in twiss_line(line, particle_ref, method, particle_on_co, R_matrix, W_matrix, delta0, zeta0, zeta_shift, r_sigma, nemitt_x, nemitt_y, delta_disp, delta_chrom, zeta_disp, co_guess, steps_r_matrix, co_search_settings, at_elements, at_s, continue_on_closed_orbit_error, freeze_longitudinal, freeze_energy, values_at_element_exit, radiation_method, eneloss_and_damping, radiation_integrals, spin, polarization, start, end, init, num_turns, skip_global_quantities, matrix_responsiveness_tol, matrix_stability_tol, symplectify, reverse, use_full_inverse, strengths, hide_thin_groups, search_for_t_rev, num_turns_search_t_rev, only_twiss_init, only_orbit, compute_R_element_by_element, compute_lattice_functions, compute_chromatic_properties, coupling_edw_teng, init_at, x, px, y, py, zeta, delta, betx, alfx, bety, alfy, bets, dx, dpx, dy, dpy, dzeta, mux, muy, muzeta, ax_chrom, bx_chrom, ay_chrom, by_chrom, ddx, ddpx, ddy, ddpy, spin_x, spin_y, spin_z, zero_at, co_search_at, include_collective, disable_apertures, _continue_if_lost, _keep_tracking_data, _keep_initial_particles, _initial_particles, _ebe_monitor, only_markers)
#     425             line.tracker.track_flags.XS_FLAG_IGNORE_GLOBAL_APERTURE = True
#     426             line.tracker.track_flags.XS_FLAG_IGNORE_LOCAL_APERTURE = True
# --> 427             out = twiss_line(**input_kwargs)
#     428             return _add_action_in_res(out, input_kwargs)
#     430 if only_markers:
#
# File ~/miniforge3/envs/xsuite_fcc_com/lib/python3.11/site-packages/xtrack/twiss.py:592, in twiss_line(line, particle_ref, method, particle_on_co, R_matrix, W_matrix, delta0, zeta0, zeta_shift, r_sigma, nemitt_x, nemitt_y, delta_disp, delta_chrom, zeta_disp, co_guess, steps_r_matrix, co_search_settings, at_elements, at_s, continue_on_closed_orbit_error, freeze_longitudinal, freeze_energy, values_at_element_exit, radiation_method, eneloss_and_damping, radiation_integrals, spin, polarization, start, end, init, num_turns, skip_global_quantities, matrix_responsiveness_tol, matrix_stability_tol, symplectify, reverse, use_full_inverse, strengths, hide_thin_groups, search_for_t_rev, num_turns_search_t_rev, only_twiss_init, only_orbit, compute_R_element_by_element, compute_lattice_functions, compute_chromatic_properties, coupling_edw_teng, init_at, x, px, y, py, zeta, delta, betx, alfx, bety, alfy, bets, dx, dpx, dy, dpy, dzeta, mux, muy, muzeta, ax_chrom, bx_chrom, ay_chrom, by_chrom, ddx, ddpx, ddy, ddpy, spin_x, spin_y, spin_z, zero_at, co_search_at, include_collective, disable_apertures, _continue_if_lost, _keep_tracking_data, _keep_initial_particles, _initial_particles, _ebe_monitor, only_markers)
#     590 if radiation_method is None and line._radiation_model is not None:
#     591     if line._radiation_model == 'quantum':
# --> 592         raise ValueError(
#     593             'twiss cannot be called when the radiation model is ``quantum``')
#     594     if method == '4d':
#     595         raise RuntimeError('4d twiss cannot be called when radiation is present')
#
# ValueError: twiss cannot be called when the radiation model is ``quantum``
